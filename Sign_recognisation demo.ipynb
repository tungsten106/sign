# %%
import torchvision
import sys,os
sys.path.append(os.pardir)
import glob as glob
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def remove_last_line(l=[""]):
    while l[-1]=="":
        l.remove(l[-1])
        
    return l

# %%
def txt_to_array(xn=""):
    x1=open(xn,"r")
    lx = x1.read().splitlines()
    lx=remove_last_line(lx)
    lx_=np.float_(lx)
    return(lx_)

# %%
path="C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0"
file_names=glob.glob(os.path.join(path,'one_pack\\one'+str(2)+'\\*.txt'))

# %%
#print(file_names)
print(len(file_names))
# Out:
# 12

# %%
xn=file_names[2]
yn=file_names[3]

# %%
# Out:
# <_io.TextIOWrapper name='C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\one_pack\\one2\\little-one-x-2.txt' mode='r' encoding='cp936'>

# %%
x1=open(xn,"r")
y1=open(yn,"r")
lx = x1.read().splitlines()
print(len(lx))
lx=remove_last_line(lx)
ly = y1.read().splitlines()
ly=remove_last_line(ly)
print(len(lx),len(ly))
# Out:
# 116
# 100 100

# %%
lx_=np.float_(lx)
ly_=np.float_(ly)

# %%
plt.plot(lx_,ly_)

# %%
lis=np.array([1,1,2])
np.delete(lis,[1])
print(lis)
# Out:
# [1 1 2]

# %%
#fingers=["fore","little","middle","palm","ring","thumb"]
path="C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0"
file_names=glob.glob(os.path.join(path,'figs\\one\\*.txt'))
#print(file_names)

try:
    os.mkdir(os.path.join(path,"one_figs"))
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    for i in range(6):
        xn=file_names[2*i]
        yn=file_names[2*i+1]

        lx_=txt_to_array(xn)
        ly_=txt_to_array(yn)

        if len(lx_)==len(ly_):
            plt.plot(lx_,ly_)
        else:
            print(len(lx_),len(ly_))


        fig_path=os.path.join(path,"one_figs\\hand1.jpg")
        plt.savefig(fig_path)
# Out:
# Creation of the directory C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0 failed

# %%
path="C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0"

# def gen_one_hand(st=""):    
#     file_names=glob.glob(os.path.join(path,'one_pack\\one'+str(st)+'\\*.txt'))
#     for i in range(6):
#         xn=file_names[2*i]
#         yn=file_names[2*i+1]

#         lx_=txt_to_array(xn)
#         ly_=txt_to_array(yn)

#         if len(lx_)==len(ly_):
#             plt.plot(lx_,ly_)

# gen_one_hand("")

# %%
gen_one_hand(2)

# %%
gen_one_hand(3)

# %%
path_one=os.path.join(path,'one_pack')
#p=os.walk(path_one)
path_one
# Out:
# 'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\one_pack'

# %%
list_one=os.listdir(path_one)
list_one
# Out:
# ['one',
#  'one10',
#  'one11',
#  'one12',
#  'one13',
#  'one14',
#  'one15',
#  'one16',
#  'one17',
#  'one18',
#  'one19',
#  'one2',
#  'one20',
#  'one21',
#  'one22',
#  'one3',
#  'one4',
#  'one5',
#  'one6',
#  'one7',
#  'one8',
#  'one9']

# %%
path="C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0"

signList=os.listdir(path)
print(signList)
# Out:
# ['eight_pack', 'five_pack', 'four_pack', 'nine_pack', 'one_pack', 'seven_pack', 'six_pack', 'ten_pack', 'three_pack', 'two_pack']

# %%
for sign in signList:
    sign_path=os.path.join(path,sign)
    print(sign_path)
    
sign_path
# Out:
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\eight_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\five_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\four_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\nine_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\one_figs
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\one_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\seven_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\six_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\ten_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\three_pack
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack
# 'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack'

# %%
packs=os.listdir(sign_path)

for pack in packs:
    pack_path=os.path.join(sign_path,pack)
# Out:
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two10
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two11
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two12
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two13
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two14
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two15
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two16
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two17
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two18
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two19
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two2
# ...

# %%
file_names=glob.glob(os.path.join(pack_path,"*.txt"))
file_names
# Out:
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0\two_pack\two9
# ['C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\fore-two-x-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\fore-two-y-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\little-two-x-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\little-two-y-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\middle-two-x-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\middle-two-y-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\palm-two-x-1.txt',
#  'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\two_pack\\two9\\palm-two-y-1.txt',
# ...

# %%
print(path)
def gen_one_hand(st=""):    
    file_names=glob.glob(os.path.join(path,'one_pack\\one'+str(st)+'\\*.txt'))
    for i in range(6):
        xn=file_names[2*i]
        yn=file_names[2*i+1]

        lx_=txt_to_array(xn)
        ly_=txt_to_array(yn)

        if len(lx_)==len(ly_):
            plt.plot(lx_,ly_)

gen_one_hand("")
# Out:
# C:\Users\yexue\Gesture-Recognition-based-on-IMU\data\rawdata_0

# %%
#"one_pack"

fig_path="C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\hand_figs\\one"

os.mkdir(fig_path)

for i in range(len(path_one)):
    path_i=path_one[i]
    file_names=glob.glob(os.path.join(path_i,'\\*.txt'))
    for i in range(6):
        xn=file_names[2*i]
        yn=file_names[2*i+1]

        lx_=txt_to_array(xn)
        ly_=txt_to_array(yn)

        if len(lx_)==len(ly_):
            plt.plot(lx_,ly_)
            
    plt.savefig(os.path.join(fig_path,"\\hand"+str(i)+".jpg"))
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-216-b9cfbc00bee3> in <module>
#       3 fig_path="C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\hand_figs\\one"
#       4
# ----> 5 os.mkdir(fig_path)
#       6
#       7 for i in range(len(path_one)):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\hand_figs\\one'

# %%
x1=open("C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\rawdata_0\\nine_pack\\nine2\\little-nine-x-1.txt","rb")
lx=x1.read().splitlines()
#type(lx)
print(lx)
str_lx=[x.decode('utf-8-sig') for x in lx]
print(str_lx)
str_lx=remove_last_line(str_lx)
np.float_(str_lx)
# Out:
# [b'\xef\xbb\xbf177.79', b'177.88', b'177.82', b'177.97', b'177.85', b'179.51', b'178.36', b'174.42', b'178.91', b'179.37', b'178.47', b'177.46', b'176.73', b'179.15', b'180.09', b'177.32', b'176.23', b'177.2', b'175.36', b'174.82', b'175.39', b'174.78', b'167.54', b'164.56', b'172.84', b'160.5', b'208.08', b'126.85', b'146.43', b'160.21', b'157.88', b'156.56', b'99.54', b'105.36', b'136.14', b'136.74', b'113.57', b'95.34', b'104.18', b'98.13', b'75.6', b'72.76', b'65.23', b'39.53', b'34.72', b'38.71', b'46.59', b'14.49', b'18.51', b'41.32', b'24.29', b'8.05', b'27.98', b'15.62', b'12.63', b'22.36', b'25.84', b'19.49', b'15.13', b'18.82', b'19.45', b'12.64', b'14.61', b'21.98', b'24.29', b'27.37', b'34.3', b'4.98', b'16.77', b'37.09', b'53.81', b'13.61', b'16.77', b'58.22', b'76.77', b'61.72', b'35.7', b'79.75', b'111.01', b'143.29', b'128.32', b'136.08', b'131.35', b'138.99', b'138.25', b'152.02', b'154.39', b'146.28', b'146.33', b'164.94', b'159.78', b'148.19', b'161.51', b'163.42',
# ...

# %%
#pytorch

from glob import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil
from torchvision import transforms
from torchvision import models
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch import optim
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
from torch.utils.data import Dataset,DataLoader
import time
# %matplotlib inline

# %%
# data renaming
import re
lis=re.findall(r'[0-9]+|[a-z]+',"eight1")
print(lis)
print(lis)
".".join(lis)
# Out:
# ['eight', '1']
# ['eight', '1']
# 'eight.1'

# %%
#dog-vs-cat

def imshow(inp):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)

# %%
path = "C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\figs_0\\"
train_path=os.path.join(path,"train")
packs=os.listdir(train_path)
packs
# Out:
# ['eight_pack',
#  'five_pack',
#  'four_pack',
#  'nine_pack',
#  'one_pack',
#  'seven_pack',
#  'six_pack',
#  'ten_pack',
#  'three_pack',
#  'two_pack']

# %%
os.mkdir(os.path.join(path,'valid'))

# %%
import math

# %%
for pack in packs:
    #print(pack)
    files=glob.glob(os.path.join(train_path,pack,"*.jpg"))
    #print(os.path.join(train_path,pack,"*.jpg"))
    #num = len(files)
    valid_size = math.floor(num/3)
    shuffle = np.random.permutation(num)
    #print(shuffle)
    
    valid_path=os.path.join(path,'valid')
    if not os.path.isdir(valid_path):
        os.mkdir(os.path.join(valid_path,pack))
    
    for i in shuffle[0:valid_size]:
        folder = files[i].split('\\')[-1].split('.')[0]
        image = files[i].split('\\')[-1]
        os.rename(files[i],os.path.join(path,'valid',folder+"_pack",image))
# Out:
# eight
# eight.21.jpg
# eight
# eight.8.jpg
# eight
# eight.20.jpg
# eight
# eight.11.jpg
# eight
# eight.7.jpg
# eight
# eight.2.jpg
# eight
# eight.14.jpg
# five
# five.17.jpg
# five
# five.5.jpg
# five
# five.4.jpg
# five
# five.9.jpg
# five
# five.1.jpg
# five
# five.13.jpg
# five
# five.6.jpg
# four
# four.20.jpg
# four
# four.1.jpg
# four
# four.16.jpg
# four
# four.9.jpg
# four
# four.21.jpg
# four
# four.12.jpg
# four
# four.18.jpg
# nine
# nine.17.jpg
# nine
# nine.22.jpg
# nine
# nine.21.jpg
# nine
# nine.7.jpg
# nine
# nine.15.jpg
# nine
# nine.1.jpg
# nine
# nine.19.jpg
# one
# one.20.jpg
# one
# one.17.jpg
# one
# one.6.jpg
# one
# one.22.jpg
# one
# one.14.jpg
# one
# one.2.jpg
# one
# one.15.jpg
# seven
# seven.13.jpg
# seven
# seven.7.jpg
# seven
# seven.22.jpg
# seven
# seven.11.jpg
# seven
# seven.16.jpg
# seven
# seven.1.jpg
# seven
# seven.18.jpg
# six
# six.14.jpg
# six
# six.4.jpg
# six
# six.12.jpg
# six
# six.15.jpg
# six
# six.10.jpg
# six
# six.11.jpg
# six
# ...

# %%
import cv2

image = cv2.imread("C:\\Users\\yexue\\Desktop\\cat.1.jpg", flags=cv2.IMREAD_COLOR)
print(image.shape)
image2 = cv2.imread("C:\\Users\\yexue\\Gesture-Recognition-based-on-IMU\\data\\figs_0\\train\\eight_pack\\eight.1.jpg")
print(image2.shape)
# Out:
# (280, 300, 3)
# (288, 432, 3)

# %%
simple_transform = transforms.Compose([transforms.Resize((224,224))
                                       ,transforms.ToTensor()
                                       ,transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
train = ImageFolder(train_path,simple_transform)
valid = ImageFolder(valid_path,simple_transform)

# %%
len(train)
# Out:
# 149

# %%
for i in range(len(train)):
    a=np.array(train[i][0])
    a=a.reshape([1,3,224,224])
    print(a.shape)
    a=torch.from_numpy(a)
    train[i][0]=a
# Out:
# (1, 3, 224, 224)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-220-0e5464edbd21> in <module>
#       4     print(a.shape)
#       5     a=torch.from_numpy(a)
# ----> 6     train[i][0]=a
#
# TypeError: 'tuple' object does not support item assignment

# %%
train[50][0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-221-35fb60f9f6a8> in <module>
# ----> 1 train[50][0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
for i in range(len(train)):
    train[i][0].expand_dims()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-5f7558a291b4> in <module>
#       1 for i in range(len(train)):
# ----> 2     train[i][0].expand_dims()
#
# AttributeError: 'Tensor' object has no attribute 'expand_dims'

# %%
torch.reshape(train[50][0],([1,3,224,224]))
print(train[50][0].shape)
# Out:
# torch.Size([3, 224, 224])

# %%
a=np.array(train[50][0])
a=a.reshape([1,3,224,224])
#print(a.shape)
a=torch.from_numpy(a)
a
a.shape
# Out:
# (1, 3, 224, 224)
# torch.Size([1, 3, 224, 224])

# %%
a=np.zeros((1,2))
a.reshape(1,1,2)
a
# Out:
# array([[0., 0.]])

# %%
for i in range(len(valid)):
    valid[i][0].reshape([1,3,224,224])

# %%
print(train.class_to_idx)
print(train.classes)
# Out:
# {'eight_pack': 0, 'five_pack': 1, 'four_pack': 2, 'nine_pack': 3, 'one_pack': 4, 'seven_pack': 5, 'six_pack': 6, 'ten_pack': 7, 'three_pack': 8, 'two_pack': 9}
# ['eight_pack', 'five_pack', 'four_pack', 'nine_pack', 'one_pack', 'seven_pack', 'six_pack', 'ten_pack', 'three_pack', 'two_pack']

# %%
train_data_loader = torch.utils.data.DataLoader(train,batch_size=1,num_workers=3,shuffle=True)
valid_data_loader = torch.utils.data.DataLoader(valid,batch_size=1,num_workers=3,shuffle=True)

# %%
dataset_sizes = {'train':len(train_data_gen.dataset),'valid':len(valid_data_gen.dataset)}

# %%
dataloaders = {'train':train_data_gen,'valid':valid_data_gen}

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(56180, 500)
        self.fc2 = nn.Linear(500,50)
        self.fc3 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = F.relu(self.fc2(x))
        x = F.dropout(x,training=self.training)
        x = self.fc3(x)
        return F.log_softmax(x,dim=1)

# %%
optimizer = optim.SGD(model.parameters(),lr=0.01,momentum=0.5)

# %%
def fit(epoch,model,data_loader,phase='training',volatile=False):
    if phase == 'training':
        model.train()
    if phase == 'validation':
        model.eval()
        volatile=True
    running_loss = 0.0
    running_correct = 0
    for batch_idx , (data,target) in enumerate(data_loader):
#         if is_cuda:
#             data,target = data.cuda(),target.cuda()
        data , target = Variable(data,volatile),Variable(target)
        if phase == 'training':
            optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output,target)
        
        running_loss += F.nll_loss(output,target,size_average=False).data[0]
        preds = output.data.max(dim=1,keepdim=True)[1]
        running_correct += preds.eq(target.data.view_as(preds)).cpu().sum()
        if phase == 'training':
            loss.backward()
            optimizer.step()
    
    loss = running_loss/len(data_loader.dataset)
    accuracy = 100. * running_correct/len(data_loader.dataset)
    
    print(f'{phase} loss is {loss:{5}.{2}} and {phase} accuracy is {running_correct}/{len(data_loader.dataset)}{accuracy:{10}.{4}}')
    return loss,accuracy

# %%
train_losses , train_accuracy = [],[]
val_losses , val_accuracy = [],[]
for epoch in range(1,20):
    epoch_loss, epoch_accuracy = fit(epoch,model,train_data_loader,phase='training')
    val_epoch_loss , val_epoch_accuracy = fit(epoch,model,valid_data_loader,phase='validation')
    train_losses.append(epoch_loss)
    train_accuracy.append(epoch_accuracy)
    val_losses.append(val_epoch_loss)
    val_accuracy.append(val_epoch_accuracy)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-138-ad34324b511a> in <module>
#       2 val_losses , val_accuracy = [],[]
#       3 for epoch in range(1,20):
# ----> 4     epoch_loss, epoch_accuracy = fit(epoch,model,train_data_loader,phase='training')
#       5     val_epoch_loss , val_epoch_accuracy = fit(epoch,model,valid_data_loader,phase='validation')
#       6     train_losses.append(epoch_loss)
#
# <ipython-input-137-f6f522d8a934> in fit(epoch, model, data_loader, phase, volatile)
#      13         if phase == 'training':
#      14             optimizer.zero_grad()
# ---> 15         output = model(data)
#      16         loss = F.nll_loss(output,target)
#      17
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# ...

# %%
train_loader=dataloaders["train"]
test_loader=dataloaders["valid"]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # 输入1通道，输出10通道，kernel 5*5
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        # fully connect
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        # in_size = 64
        in_size = x.size(0) # one batch
        # x: 64*10*12*12
        x = F.relu(self.mp(self.conv1(x)))
        # x: 64*20*4*4
        x = F.relu(self.mp(self.conv2(x)))
        # x: 64*320
        x = x.view(in_size, -1) # flatten the tensor
        # x: 64*10
        x = self.fc(x)
        return F.log_softmax(x)


model = Net()

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

def train(epoch):
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data[0]))


def test():
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        # sum up batch loss
        test_loss += F.nll_loss(output, target, size_average=False).data[0]
        # get the index of the max log-probability
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))


for epoch in range(1, 10):
    train(epoch)
    test()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-60-cfc48233a6a7> in <module>
#      60
#      61 for epoch in range(1, 10):
# ---> 62     train(epoch)
#      63     test()
#
# <ipython-input-60-cfc48233a6a7> in train(epoch)
#      31         data, target = Variable(data), Variable(target)
#      32         optimizer.zero_grad()
# ---> 33         output = model(data)
#      34         loss = F.nll_loss(output, target)
#      35         loss.backward()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ...
